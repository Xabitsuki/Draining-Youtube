# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.insert(0, '../source/')
from analysis_functions import *

# %% [markdown]
# This notebook is used to help the exploration of the generated 3D models whithout having to manualy go through all the files to find the richer 3D models.
#
# Simply pass the path to a folder containing "video" folders (folder generated by the draining pipeline named using the YouTube ID fo the video) to PLYLST_FOLDER:

# %%
PLYLST_FOLDER = 'local/test_video'

# %% [markdown]
# Create a dataframe resuming information of all the sets present in the playlist folder.

# %%
df = get_df_playlist(PLYLST_FOLDER)

# %% [markdown]
# Sort the data frame such that the sets that lead to 3D models with greatedt number of vertices appear first.

# %%
df.sort_values(by='Number of Vertices', ascending=False)[:10]
# Out:
#                               Playlist   Youtube ID        Format  Duration  \
# 8   /Users/xrubiato/Desktop/test_video  LnyKeqdzQao  [1920, 1012]       187
# 14  /Users/xrubiato/Desktop/test_video  LnyKeqdzQao  [1920, 1012]       187
# 0   /Users/xrubiato/Desktop/test_video  LnyKeqdzQao  [1920, 1012]       187
# 13  /Users/xrubiato/Desktop/test_video  LnyKeqdzQao  [1920, 1012]       187
# 4   /Users/xrubiato/Desktop/test_video  LnyKeqdzQao  [1920, 1012]       187
# 11  /Users/xrubiato/Desktop/test_video  LnyKeqdzQao  [1920, 1012]       187
# 16  /Users/xrubiato/Desktop/test_video  LnyKeqdzQao  [1920, 1012]       187
# 2   /Users/xrubiato/Desktop/test_video  LnyKeqdzQao  [1920, 1012]       187
# 15  /Users/xrubiato/Desktop/test_video  LnyKeqdzQao  [1920, 1012]       187
# 6   /Users/xrubiato/Desktop/test_video  LnyKeqdzQao  [1920, 1012]       187
#
#     Extract Rate  Frames Total  Number of sets  Set Number  Frames in Set  \
# ...
